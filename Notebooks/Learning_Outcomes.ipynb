# %% [markdown]
# # **Analyzing the Impact of Engagement on Skill Development in Various Art Forms**

# %% [markdown]
# ## **Project Overview**
# This project explores the influence of attendance, participation, and leadership on skill development across various art forms, such as animation, music composition, and visual arts. Using Tableau, I created a series of visualizations to uncover key insights into how these different modes of engagement impact personal and professional growth.
#
# The analysis focuses on:
#
# - Overall Impact: Identifying which type of engagement has the greatest effect on skill development.
# - Significance Distribution: Visualizing the frequency of statistically significant results (`*`, `**`, `***`) for each engagement type.
# - Skill-Specific Impact: Highlighting which skills, such as creativity or problem-solving, are most affected by each engagement type across different art forms.
#
# The project aims to provide actionable insights for students, educators, and institutions to better understand how different forms of engagement contribute to skill growth and inform strategies for fostering personal and professional development in creative fields.

# %% [markdown]
# ### **Objective**
# The objective of this project is to:
# 1. Analyze the overall impact of attendance, participation, and leadership on skill development across various art forms.
# 2. Visualize the distribution of statistical significance for each engagement type to determine which type of engagement (attendance, participation, or leadership) consistently shows the strongest influence on skill development.
# 3. Highlight the specific skills most significantly affected by engagement types through a detailed comparison of art forms and skill impact.

# %% [markdown]
# ### **Process**
# - **Data Preparation**: Consolidated and organized data across multiple art forms, focusing on the coefficient values and significance levels for attendance, participation, and leadership.
# - **Visualization**: Designed and developed three key Tableau visualizations — a bar chart for comparing engagement impacts, a pie chart for the distribution of significance levels, and a heatmap to show skill-specific impacts across art forms.
# - **Analysis**: Analyzed the visualizations to understand how different types of engagement influence skill development, identifying trends and drawing conclusions from the distribution of significance levels and the strength of engagement effects across art forms.

# %% [markdown]
# ### **Visualizations**
#
# #### **Overall Impact of Engagement Types Across Art Forms**
#
# This bar chart compares the coefficients for attendance, participation, and leadership across multiple art forms, showing the impact each engagement type has on skill development.
#
# **Key Insights:** Leadership generally has the strongest influence, particularly in music performance and visual arts. Participation and attendance have moderate, but still meaningful, impacts in most cases.

# %%
from IPython.display import Image, display

display(Image(filename='Overall Impact of Engagement Types.png'))

# %% [markdown]
# #### **Skill Impact by Art Form (Heatmap)**
#
# This heatmap visualizes the significance of various engagement types (attendance, participation, leadership) in impacting different skills across art forms. Darker colors represent higher significance levels.
#
# **Key Insights:** Some art forms, such as animation and music composition, show strong engagement effects on skills like creativity and problem-solving. This can guide students toward activities where their involvement has the most impact.

# %%
display(Image(filename='Skill Impact by Art Form Across Engagement Types.png'))

# %% [markdown]
# #### **Distribution of Significance Levels Across Engagement Types**
#
# This pie chart visualizes the distribution of statistical significance (`*`, `**`, `***`) for engagement types: attendance, participation, and leadership.
#
# **Key Insights:** Leadership has a high proportion of `***` significance, showing that it plays a critical role in skill development. Attendance and participation also show some significant effects, though less frequently.

# %%
display(Image(filename='Distribution of Significance Levels Across Engagement Types.png', width=400))

# %% [markdown]
# #### **Complete Dashboard Overview**
#
# This dashboard brings together the three visualizations to give a comprehensive view of how attendance, participation, and leadership impact skill development across different art forms.

# %%
display(Image(filename='Dashboard 1.png'))

# %% [markdown]
# ### **Conclusion**
#
# The project demonstrates how different forms of engagement (attendance, participation, leadership) contribute to skill development across various art forms.
#
# **Leadership** has the most profound effect on key skills such as creativity, problem-solving, and collaboration, making it a crucial engagement type for students. **Participation** also contributes meaningfully, particularly in more creative fields such as music and visual arts. **Attendance** has a more moderate effect but still plays a role in shaping students' open-mindedness and perspective.
#
# These insights can help educators tailor their programs to focus on the most impactful engagement types for each art form.
